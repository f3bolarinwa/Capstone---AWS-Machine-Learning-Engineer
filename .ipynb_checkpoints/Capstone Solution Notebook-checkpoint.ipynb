# %% [markdown]
# # Capstone - AWS Machine Learning Engineer Nanodegree
# ## AEP Hourly Power Consumption Forecast
# ### by 'Femi Bolarinwa

# %%
# !pip install xgboost
# !pip install -U pip
# !pip install -U setuptools wheel
# !pip install autogluon --no-cache-dir
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from xgboost) (1.11.3)
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 1.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3

# %% [markdown]
# ### Importing Libraries

# %%
import os
import boto3
import sagemaker
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
#library for signal filtering
from scipy import signal

# Library for statistical test of stationarity
from statsmodels.tsa.stattools import adfuller

#Library for time series decomposition
import statsmodels.api as sm

#Library to create auto-correlation and partial auto-correlation plots
from statsmodels.graphics import tsaplots

#Libraries to build AR, MA, ARMA, and SARIMA time-series models
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.ar_model import AutoReg

# %% [markdown]
# ### AWS Macros

# %%
session = sagemaker.Session()
bucket= session.default_bucket()
region = session.boto_region_name
role = sagemaker.get_execution_role()

# %%
# !unzip AEP_hourly.csv.zip
# Out:
# Archive:  AEP_hourly.csv.zip
#   inflating: AEP_hourly.csv

# %% [markdown]
# os.environ["DATABASE_PATH"] = "s3://"+ bucket+ "/AEP_hourly/"
# !aws s3 cp AEP_hourly ${DATABASE_PATH} --recursive

# %% [markdown]
# ### Data Overview

# %%
df = pd.read_csv('AEP_hourly.csv')

# %%
#viewing dataframe head
df.head()
# Out:
#               Datetime   AEP_MW
# 0  2004-12-31 01:00:00  13478.0
# 1  2004-12-31 02:00:00  12865.0
# 2  2004-12-31 03:00:00  12577.0
# 3  2004-12-31 04:00:00  12517.0
# 4  2004-12-31 05:00:00  12670.0

# %%
df.tail()
# Out:
#                    Datetime   AEP_MW
# 121268  2018-01-01 20:00:00  21089.0
# 121269  2018-01-01 21:00:00  20999.0
# 121270  2018-01-01 22:00:00  20820.0
# 121271  2018-01-01 23:00:00  20415.0
# 121272  2018-01-02 00:00:00  19993.0

# %%
#checking for duplicate rows in dataframe
duplicate_df = df[df.duplicated()]

print("Number of duplicate Rows except first occurrence based on all columns are:")
duplicate_df.sum()
# Out:
# Number of duplicate Rows except first occurrence based on all columns are:
# Datetime      0
# AEP_MW      0.0
# dtype: object

# %%
#checking data size
df.shape
# Out:
# (121273, 2)

# %%
#checking data types of features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121273 entries, 0 to 121272
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  121273 non-null  object
#  1   AEP_MW    121273 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB

# %%
#checking missing value
df.isnull().sum()
# Out:
# Datetime    0
# AEP_MW      0
# dtype: int64

# %%
#checking for missing hours in the time-series
out = pd.date_range(df['Datetime'].min(), df['Datetime'].max(), freq='H').difference(df['Datetime'])
print(out)
# Out:
# DatetimeIndex(['2004-10-31 02:00:00', '2005-04-03 03:00:00',
#                '2005-10-30 02:00:00', '2006-04-02 03:00:00',
#                '2006-10-29 02:00:00', '2007-03-11 03:00:00',
#                '2007-11-04 02:00:00', '2008-03-09 03:00:00',
#                '2008-11-02 02:00:00', '2009-03-08 03:00:00',
#                '2009-11-01 02:00:00', '2010-03-14 03:00:00',
#                '2010-11-07 02:00:00', '2010-12-10 00:00:00',
#                '2011-03-13 03:00:00', '2011-11-06 02:00:00',
#                '2012-03-11 03:00:00', '2012-11-04 02:00:00',
#                '2012-12-06 04:00:00', '2013-03-10 03:00:00',
#                '2013-11-03 02:00:00', '2014-03-09 03:00:00',
#                '2014-03-11 14:00:00', '2015-03-08 03:00:00',
#                '2016-03-13 03:00:00', '2017-03-12 03:00:00',
#                '2018-03-11 03:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
#since this is a time-series problem, i'll be setting 'Datetime' as index
df = df.set_index('Datetime')
df.index = pd.to_datetime(df.index)

# %%
#sorting index in ascending order
df.sort_index(inplace=True)

# %%
#resampling and filling missing hours with preceeding hour's energy value 
df = df.resample('H').first().fillna(method='ffill')
# Out:
# /tmp/ipykernel_6919/926166468.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.resample('H').first().fillna(method='ffill')

# %%
#checking missing hours again
out = pd.date_range(df.index.min(), df.index.max(), freq='H').difference(df.index)
print(out)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='H')

# %%
df.head()
# Out:
#                       AEP_MW
# Datetime
# 2004-10-01 01:00:00  12379.0
# 2004-10-01 02:00:00  11935.0
# 2004-10-01 03:00:00  11692.0
# 2004-10-01 04:00:00  11597.0
# 2004-10-01 05:00:00  11681.0

# %%
#checking final dataframe tail
df.tail()
# Out:
#                       AEP_MW
# Datetime
# 2018-08-02 20:00:00  17673.0
# 2018-08-02 21:00:00  17303.0
# 2018-08-02 22:00:00  17001.0
# 2018-08-02 23:00:00  15964.0
# 2018-08-03 00:00:00  14809.0

# %% [markdown]
# ### Data Visualization and Statistical Analysis

# %%
#checking descriptive statistics of timeseries
round(df.describe(),2)
# Out:
#           AEP_MW
# count  121296.00
# mean    15499.18
# std      2591.36
# min      9581.00
# 25%     13629.00
# 50%     15309.00
# 75%     17200.00
# max     25695.00

# %%
#visualing dataset

df.plot(style='.',
        figsize=(15, 5),
        color=color_pal[0],
        title='Energy Use in MW')
plt.show()

# %%
df.loc[(df.index > '01-01-2010') & (df.index < '01-08-2010')] \
    .plot(figsize=(15, 5), title='One Week Of Data')
plt.show()

# %% [markdown]
# #### Decomposition of Time-series
# I'll be decomposing the time-series to separately visualize its:
#
# - Trend
# - Seasonality
# - Residual/White/Random Noise

# %%
decomposition = sm.tsa.seasonal_decompose(df, period = 9)

# %%
#Visualizing time series components in a single plot
plt.figure(figsize = (15, 10))

plt.subplot(411)
plt.plot(df, label = 'Original Time-series')
plt.legend(loc = 'upper right')

plt.subplot(412)
plt.plot(decomposition.trend, label = 'Trend')
plt.legend(loc = 'upper right')

plt.subplot(413)
plt.plot(decomposition.seasonal, label = 'Seasonality')
plt.legend(loc = 'upper right')

plt.subplot(414)
plt.plot(decomposition.resid, label = 'White Noise')
plt.legend(loc = 'upper right')

plt.tight_layout()

# %% [markdown]
# Observations:
#
# - The trend contains a substantial level of high frequency noise.
# - Although a 4-season seasonality (likely corresponding to energy consumptions in fall, winter, spring and summer) is visually evident in the series (going by the peaks and troughs), the time series decomposition does not indicate any significant seasonality (observe the scale). This can be attributed to the extreme high frequency noise present in the series.
# - The two points metioned above makes accurate time-series modelling and prediction very challenging.

# %% [markdown]
# ### Train/Test Split
#
# I'll be splitting the data into train and test data at ratio 75:25. Train data will be used to build models, while test data will be used to make prediction/forecast and evaluate perfromance of models

# %%
train = df.loc[df.index < '01-01-2015']
test = df.loc[df.index >= '01-01-2015']

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('01-01-2015', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %% [markdown]
# ### Model Evaluation Metrics
# Before embarking on model building, i need to select which evaluation metrics to assess the models against:
#
# MAE
# Mean absolute error is how far away the forecasts are in comparison to the actual values in the time series. Its measured as the mean of the absolute error between all predictions and corresponding actual value.
#
# RMSE
# Root mean square error also measures how far away the forecasts are in comparison to the actual values, but its the mean of the squares of the error between time-series values and correspond forecast.

# %% [markdown]
# ### Custom function for model performance evaluation

# %%
def plot_predicted_output(model, ax):
    
    """
    Function to visualize prediction
    Input: model, pyplot object
    Output: plots of predictions
    """
    
    predictions_test = model.predict(start=train.shape[0],end=(train.shape[0]+test.shape[0]-1)) 
    predictions_train = model.predict(start=0,end=(train.shape[0]-1))

    # Setting indices of the test data into prediction values
    predictions_test.index = test.index
    predictions_train.index = train.index
    
    # Computing the AIC and RMSE metrics for the model and printing it into title of the plot
    train.plot(ax = ax, label = 'train', linestyle = 'dashed',
                    title = 'AIC: {}'.format(np.round(model.aic, 2)) + 
                           ' , ' +
                           'MAE on Test Data: {}'.format(np.round(np.sqrt(mean_absolute_error(test, predictions_test)), 2)+
                            ' , ' +                              
                           'RMSE on Test Data: {}'.format(np.round(np.sqrt(mean_squared_error(test, predictions_test)), 2)))
    
    # Plotting the test data
    test.plot(ax = ax)#, color = 'green', linestyle = 'dashed',) 
    
    # Plotting the forecasted data
    predictions_test.plot(ax = ax)#, color = 'yellow')
    predictions_train.plot(ax = ax, linestyle = 'dashed')#, color = 'green')
    
    # Adding the legends sequentially
    ax.legend(['train data', 'test data', 'forecast on test data', 'forecast on train data'])

# %% [markdown]
# ### Modelling
# #### Baseline Model - Moving Average (MA)
#
# The Moving Average modelling of time-series is essentially a linear regression that makes use of the past error terms as predictors. Forecast (prediction) at any time in the future is the linear combination of weighted past residuals. The name should not be confused to mean moving average of past datapoints. Instead, it is the linear combination of past error terms.
#
# The number of lags to be used in MA is called the order of MA. And its selected to include lags that have the most statistically significant correlation to the series
#
# #### Feature Engineering - Auto Correlation Function
# Auto Correlation Function (ACF) plot is a bar chart of coefficients of correlation between a time series and its lags. In simple terms, ACF explains how the present value of a given time series is correlated with its past values (1-unit past,.…, n-unit past).
#
# We can estimate the optimal order of MA from the ACF plot. It can be observed by how many lags are above or below the confidence interval (i.e have statistically significant correlation to the series).

# %%
plt.figure(figsize = (16, 5))

# Creating and plotting the ACF charts starting from lag = 1
tsaplots.plot_acf(train, zero = False)
plt.show()

# %% [markdown]
# Observation:
#
# - On the x-axis are the lags of the series. On the y-axis are the correlations between each lag and the series.
# - Correlation could be positive or negative ranging from 1 to -1.
# - The light blue shaded region represent the confidence interval
# - More than 40 lags are above the confidence interval (i.e have statistically significant positive correlation with the series).
# - Since each lag is a feature/predictor, i'll limit my q-parameter (order of MA) to 15
# - After seeing how much computation time and memory needed for 15 lags, I'll limit my order of MA to first 5 lags with the most correlations

# %%
# Creating MA model with parameter q = 5
ma_model = ARIMA(train, order = (0, 0, 5)).fit()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#statistical summary of MA model

print(ma_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 AEP_MW   No. Observations:                89855
# Model:                 ARIMA(0, 0, 5)   Log Likelihood             -689112.382
# Date:                Mon, 18 Dec 2023   AIC                        1378238.763
# Time:                        18:28:44   BIC                        1378304.605
# Sample:                    10-01-2004   HQIC                       1378258.841
#                          - 12-31-2014
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.574e+04     12.527   1256.617      0.000    1.57e+04    1.58e+04
# ma.L1          1.4210      0.001   1073.505      0.000       1.418       1.424
# ma.L2          1.2784      0.002    748.574      0.000       1.275       1.282
# ma.L3          1.3927      0.001   1538.540      0.000       1.391       1.394
# ma.L4          1.3737      0.002    857.118      0.000       1.371       1.377
# ma.L5          0.6978      0.002    447.017      0.000       0.695       0.701
# sigma2      2.702e+05    706.894    382.258      0.000    2.69e+05    2.72e+05
# ===================================================================================
# Ljung-Box (L1) (Q):               28754.54   Jarque-Bera (JB):            261224.01
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.89   Skew:                             0.14
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Observation:
#
# - All MA coefficients have p-values of less than 5% which means they are statistically significant or have enough predictive power to predict the target variable.
# - The true value of the coefficients of the independent predictors lie within the confidence interval with a 95% likelihood.
# - Each 'coef' represents the change in the output Y due to a change of one unit in the variable (everything else held constant).
# - 'std err' reflects the level of accuracy of the coefficients. The lower it is, the more accurate the coefficients are.
# - AIC (Akaike Information Criterion) is a measure of goodness of fit on the training data
# - BIC (Bayesian information criterion) or Schwarz information criterion (also SIC, SBC, SBIC) is a criterion for model selection (like AIC) among a finite set of models; models with lower BIC are generally preferred

# %% [markdown]
# #### Performance Evaluation of Base Model

# %%
# Plotting the predictions along with train and test
fig, ax = plt.subplots(figsize = (16, 6))
plot_predicted_output(ma_model, ax)

# %% [markdown]
# Observation:
#
# - Predictions on unseen test data appear to quickly run towards the long-run mean of the series
# - The performance on unseen testcdata could be improved if i would include more lags that have statistically significant correlation. However, i didnt because the model building did not run in reasonable time

# %% [markdown]
# ### Model 1 - AutoRegressive (AR)
#
# In AR, the forecast of a series at time t is a linear function of the previous values of the same time series. The order p of an autoregression model is the number of lags in the series that are used to predict the value at the present time.
#
# The number of lags to be used in AR is called the order of AR. And its selected to include lags that have the most statistically significant correlation to the series.
#
# #### Feature Engineering - Partial Auto Correlation Function (PACF)
# PACF describes the partial correlation between the series and its own lags. The partial correlation for a lag is the unique correlation between the series and that lag after taking out the intervening correlations of other lags.
#
# We can estimate the optimal lags for AR Model from the PACF plot. It can be observed by how many lags are outside the confidence interval (i.e have statistically significant partial correlation with the series).

# %%
plt.figure(figsize = (16, 5))

# Creating and plotting the PACF charts starting from lag = 1
tsaplots.plot_pacf(train, zero = False)
plt.show()

# %% [markdown]
# Observation:
#
# - The light blue shaded region represent the confidence interval. Not visible here because the confidence interval is very thin
# - Almost 50 lags have statistically significant partial-correlation to the series.
# - Each lag is a potential feature/predictor. However its not advisable to build a model with all lags because it wont run in a reasonable time.
# - Lags 1, 2, 3, 23, 24, 25 and 26 have the most statistically significant partial-correlation. However, model building ran endlessly for the size of the train data.
# - After experimenting and seeing how much computation time and memory needed for different combinations of lags, I settle for the first 4 lags
# - There is always a need to factor in the computation demand of higher lags even if they have significant correlation to the series

# %%
# Creating an AR model with parameter p = 4

ar_model = ARIMA(train, order = (4, 0, 0)).fit()

# %%
#statistical summary of AR model
print(ar_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 AEP_MW   No. Observations:                89855
# Model:                 ARIMA(4, 0, 0)   Log Likelihood             -647058.056
# Date:                Mon, 18 Dec 2023   AIC                        1294128.112
# Time:                        18:33:39   BIC                        1294184.547
# Sample:                    10-01-2004   HQIC                       1294145.321
#                          - 12-31-2014
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.574e+04     33.864    464.835      0.000    1.57e+04    1.58e+04
# ar.L1          1.9880      0.001   1447.791      0.000       1.985       1.991
# ar.L2         -1.3382      0.001   -991.508      0.000      -1.341      -1.336
# ar.L3          0.3721      0.002    162.449      0.000       0.368       0.377
# ar.L4         -0.0575      0.002    -28.566      0.000      -0.061      -0.054
# sigma2      1.053e+05    148.534    708.775      0.000    1.05e+05    1.06e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.79   Jarque-Bera (JB):         101934117.74
# Prob(Q):                              0.18   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.85   Skew:                            -1.49
# Prob(H) (two-sided):                  0.00   Kurtosis:                       167.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### Performance Evaluation

# %%
# Plotting the forecasted values along with train and test

fig, ax = plt.subplots(figsize = (16, 6))

plot_predicted_output(ar_model, ax)

# %% [markdown]
# ### Model 2 - AutoRegressive Moving Average (ARMA)
#
# ARMA is simply the combination of the Autoregressive and moving average models. Forecast at any time is a linear function of past values and past errors/residuals.
#
# Similarly, optimal orders of AR and MA can be obtained from the PACF and ACF plots respectively.

# %%
# Creating an ARMA model with parameters p = 4 and q = 5
arma_model = ARIMA(train, order = (4, 0, 5)).fit()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#statistical summary of ARMA model
print(arma_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 AEP_MW   No. Observations:                89855
# Model:                 ARIMA(4, 0, 5)   Log Likelihood             -640810.669
# Date:                Mon, 18 Dec 2023   AIC                        1281643.338
# Time:                        18:40:37   BIC                        1281746.803
# Sample:                    10-01-2004   HQIC                       1281674.889
#                          - 12-31-2014
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.574e+04     43.288    363.642      0.000    1.57e+04    1.58e+04
# ar.L1          3.3411      0.019    173.719      0.000       3.303       3.379
# ar.L2         -4.4322      0.050    -88.839      0.000      -4.530      -4.334
# ar.L3          2.7412      0.048     57.530      0.000       2.648       2.835
# ar.L4         -0.6581      0.017    -39.683      0.000      -0.691      -0.626
# ma.L1         -1.4566      0.019    -75.427      0.000      -1.494      -1.419
# ma.L2          0.5135      0.014     37.547      0.000       0.487       0.540
# ma.L3          0.3278      0.002    138.737      0.000       0.323       0.332
# ma.L4          0.0440      0.006      7.991      0.000       0.033       0.055
# ma.L5         -0.1495      0.008    -18.886      0.000      -0.165      -0.134
# sigma2      9.912e+04    151.857    652.744      0.000    9.88e+04    9.94e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.33   Jarque-Bera (JB):         106344442.34
# Prob(Q):                              0.25   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -1.62
# Prob(H) (two-sided):                  0.00   Kurtosis:                       171.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### Performance Evaluation

# %%
# Plotting the forecasted values along with train and test for all the models

fig, ax = plt.subplots(figsize = (16, 6))

plot_predicted_output(arma_model, ax)

# %% [markdown]
# Observation
#
# - It appears the ARIMA class of modeling is not a good fit for this problem
# - all model predictions on unseen test data appear to run towards the long-run mean of the series,
# - I'll try other modelling techniques

# %% [markdown]
# ### Regression Modeling
#
# I'll attempt to approach this as a linear regression problem

# %% [markdown]
# #### Feature Engineering
#
# I'll generate features from the datetime

# %%
#custom function to generate features from datetime

def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

# %% [markdown]
# #### Hourly Distribution of Energy

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='hour', y='AEP_MW')
ax.set_title('MW by Hour')
plt.show()

# %% [markdown]
# Observation
#
# - Daily energy demand appears to deep at around 4AM and reaches peak at around 7PM

# %% [markdown]
# #### Monthly Distribution of Energy

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='AEP_MW', palette='Blues')
ax.set_title('MW by Month')
plt.show()
# Out:
# /tmp/ipykernel_6919/3087536141.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='month', y='AEP_MW', palette='Blues')

# %% [markdown]
# Observation
#
# - Energy usage appears to peak at winter and summer time

# %% [markdown]
# #### Feature Engineering for Train/Test Dataset

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
TARGET = ['AEP_MW']

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
train = X_train.join(y_train)

# %%
#CSV file generation

train.to_csv('train.csv', header=False, index=False)
test.to_csv('test.csv', header=False, index=False)

# %%
#uploading files to Amazon S3

os.environ["DEFAULT_S3_BUCKET"] = bucket
# !aws s3 cp ./train.csv s3://${DEFAULT_S3_BUCKET}/train/
# !aws s3 cp ./test.csv s3://${DEFAULT_S3_BUCKET}/test/
#!aws s3 sync ./test s3://${DEFAULT_S3_BUCKET}/test/
# Out:
# upload: ./train.csv to s3://sagemaker-us-east-1-354600943736/train/train.csv
# upload: ./test.csv to s3://sagemaker-us-east-1-354600943736/test/test.csv

# %% [markdown]
# ### XGBoost Regression Modelling

# %%
reg = xgb.XGBRegressor(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=200)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:2300.89278	validation_1-rmse:2438.59290
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [23:03:51] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [23:03:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "num_round" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [32]	validation_0-rmse:1151.74961	validation_1-rmse:1665.64422
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=10,
#              enable_categorical=False, eta=0.2, eval_metric=None,
#              feature_types=None, gamma=4, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=6, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# #### Feature Importance
#
# Indicating features with the most predictive power

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %% [markdown]
# Observation
#
# - Hour of the day and month of the year appear to have the most predective power. The year, least

# %% [markdown]
# #### Performance Evaluation

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df[['AEP_MW']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Dat and Prediction')
plt.show()

# %%
ax = df.loc[(df.index > '04-01-2018') & (df.index < '04-08-2018')]['AEP_MW'] \
    .plot(figsize=(15, 5), title='Week Of Data')
df.loc[(df.index > '04-01-2018') & (df.index < '04-08-2018')]['prediction'] \
    .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()

# %% [markdown]
# #### Evaluation Metrics for XGBoost Regressor Model

# %%
score = np.sqrt(mean_squared_error(test['AEP_MW'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 1647.22

# %%
score = np.sqrt(mean_absolute_error(test['AEP_MW'], test['prediction']))
print(f'MAE Score on Test set: {score:0.2f}')
# Out:
# MAE Score on Test set: 36.06

# %% [markdown]
# MAE of 36.06MW means that you can expect the XGboost regressor model to forecast hourly energy consumption rate correctly within 36.06MW of actual consumption. The regressor model forecast follows the trend of the unseen test data while the ARIMA models appear to forecast the long running mean of the dataset. The xgboost regressor model is a far better predictive model than the ARIMA models both quantitavely and qualitatively

# %% [markdown]
# ### Model Training and Deployment on Amazon Sagemaker

# %%
#initializing sagemaker estimator with appropriate computing resources

from sagemaker import image_uris
container = image_uris.retrieve('xgboost', session.boto_region_name, version='latest')
##defining s3 bucket location to save data
s3_output_location = f"s3://{bucket}/models/image_model"

xgb_reg=sagemaker.estimator.Estimator(image_uri=container, 
                              role=role, 
                              instance_count=1,
                              instance_type='ml.m4.xlarge', #'ml.p2.xlarge',#'ml.t3.medium',#'ml.m3.xlarge',
                              output_path=s3_output_location,
                              sagemaker_session=session
)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
#setting model hyper parameters

xgb_reg.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=200)

# %%
from sagemaker.session import TrainingInput
#input_train = sagemaker.inputs.TrainingInput(s3_data=train, content_type='csv')
#({"training": "s3://"+ bucket+ "/dogImages/"}, wait=False)

train_location = "s3://"+ bucket+ "/train/"
s3_input_train = sagemaker.inputs.TrainingInput(s3_data=train_location, content_type='csv')

xgb_reg.fit({'train': s3_input_train}) #fit({"train": "s3://"+ bucket+ "/train/"}, wait=False)#    ({'train': input_train}) #X_train, y_train)#,
        #eval_set=[(X_train, y_train), (X_test, y_test)],
        #verbose=100)#
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-2023-12-23-22-53-17-262
# 2023-12-23 22:53:17 Starting - Starting the training job...
# 2023-12-23 22:53:42 Starting - Preparing the instances for training.........
# 2023-12-23 22:55:00 Downloading - Downloading input data...
# 2023-12-23 22:55:34 Downloading - Downloading the training image......
# 2023-12-23 22:56:45 Training - Training image download completed. Training in progress.
# 2023-12-23 22:56:45 Uploading - Uploading generated training modelArguments: train
# [2023-12-23:22:56:33:INFO] Running standalone xgboost training.
# [2023-12-23:22:56:33:INFO] Path /opt/ml/input/data/validation does not exist!
# [2023-12-23:22:56:33:INFO] File size need to be processed in the node: 2.19mb. Available memory size in the node: 8532.5mb
# [2023-12-23:22:56:33:INFO] Determined delimiter of CSV input is ','
# [22:56:33] S3DistributionType set as FullyReplicated
# [22:56:33] 89855x6 matrix with 539130 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [22:56:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-rmse:171.478
# Will train until train-rmse hasn't improved in 10 rounds.
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [1]#011train-rmse:137.286
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [2]#011train-rmse:109.956
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [3]#011train-rmse:88.1221
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [4]#011train-rmse:70.6919
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [5]#011train-rmse:56.7938
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [6]#011train-rmse:45.7297
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-rmse:36.9512
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [8]#011train-rmse:30.0043
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [9]#011train-rmse:24.5532
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [10]#011train-rmse:20.3047
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [11]#011train-rmse:17.031
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:14.5548
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-rmse:12.7196
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [14]#011train-rmse:11.3872
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-rmse:10.4385
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [16]#011train-rmse:9.78117
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [17]#011train-rmse:9.33524
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [18]#011train-rmse:9.0361
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19]#011train-rmse:8.83131
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [20]#011train-rmse:8.69683
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [21]#011train-rmse:8.60422
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [22]#011train-rmse:8.5442
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23]#011train-rmse:8.50041
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [24]#011train-rmse:8.46632
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [25]#011train-rmse:8.44622
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [26]#011train-rmse:8.42889
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [27]#011train-rmse:8.41721
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [28]#011train-rmse:8.40725
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [29]#011train-rmse:8.39879
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [30]#011train-rmse:8.39024
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [31]#011train-rmse:8.38496
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [32]#011train-rmse:8.37926
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [33]#011train-rmse:8.37482
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [34]#011train-rmse:8.37312
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [35]#011train-rmse:8.36842
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [36]#011train-rmse:8.36283
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [37]#011train-rmse:8.36079
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [38]#011train-rmse:8.35875
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [39]#011train-rmse:8.35714
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=5
# [40]#011train-rmse:8.34929
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [41]#011train-rmse:8.34393
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [42]#011train-rmse:8.33847
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=5
# [43]#011train-rmse:8.33709
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [44]#011train-rmse:8.33341
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [45]#011train-rmse:8.33227
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [46]#011train-rmse:8.32965
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [47]#011train-rmse:8.32573
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [48]#011train-rmse:8.32329
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [49]#011train-rmse:8.31796
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [50]#011train-rmse:8.31551
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [51]#011train-rmse:8.3125
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [52]#011train-rmse:8.30758
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [53]#011train-rmse:8.30622
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=5
# [54]#011train-rmse:8.30534
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [55]#011train-rmse:8.30064
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [56]#011train-rmse:8.29882
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [57]#011train-rmse:8.29814
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [58]#011train-rmse:8.28792
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [59]#011train-rmse:8.28757
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [60]#011train-rmse:8.28032
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [61]#011train-rmse:8.27665
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [62]#011train-rmse:8.27485
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [63]#011train-rmse:8.27265
# [22:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [64]#011train-rmse:8.26986
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [65]#011train-rmse:8.2685
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [66]#011train-rmse:8.26587
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [67]#011train-rmse:8.26409
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [68]#011train-rmse:8.26216
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [69]#011train-rmse:8.25908
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [70]#011train-rmse:8.25684
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [71]#011train-rmse:8.25101
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [72]#011train-rmse:8.24942
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [73]#011train-rmse:8.24659
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [74]#011train-rmse:8.24412
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [75]#011train-rmse:8.24266
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [76]#011train-rmse:8.24179
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [77]#011train-rmse:8.23998
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [78]#011train-rmse:8.23805
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [79]#011train-rmse:8.23391
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [80]#011train-rmse:8.23141
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [81]#011train-rmse:8.22593
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [82]#011train-rmse:8.22425
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [83]#011train-rmse:8.2227
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [84]#011train-rmse:8.22199
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [85]#011train-rmse:8.21699
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [86]#011train-rmse:8.21093
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=5
# [87]#011train-rmse:8.20884
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [88]#011train-rmse:8.20744
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [89]#011train-rmse:8.2058
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [90]#011train-rmse:8.20398
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [91]#011train-rmse:8.19906
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [92]#011train-rmse:8.19655
# [22:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [93]#011train-rmse:8.19389
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [94]#011train-rmse:8.1881
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [95]#011train-rmse:8.18549
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [96]#011train-rmse:8.18098
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [97]#011train-rmse:8.1781
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [98]#011train-rmse:8.17617
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [99]#011train-rmse:8.17537
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [100]#011train-rmse:8.17381
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [101]#011train-rmse:8.17107
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [102]#011train-rmse:8.16886
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [103]#011train-rmse:8.16813
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [104]#011train-rmse:8.16663
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [105]#011train-rmse:8.16555
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=5
# [106]#011train-rmse:8.1635
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [107]#011train-rmse:8.16281
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [108]#011train-rmse:8.16056
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [109]#011train-rmse:8.15939
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [110]#011train-rmse:8.15603
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [111]#011train-rmse:8.15422
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [112]#011train-rmse:8.15106
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [113]#011train-rmse:8.14549
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [114]#011train-rmse:8.14178
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [115]#011train-rmse:8.13698
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [116]#011train-rmse:8.1337
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [117]#011train-rmse:8.13139
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [118]#011train-rmse:8.12881
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [119]#011train-rmse:8.12592
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [120]#011train-rmse:8.12551
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [121]#011train-rmse:8.12115
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [122]#011train-rmse:8.11993
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [123]#011train-rmse:8.11771
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [124]#011train-rmse:8.11682
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [125]#011train-rmse:8.1145
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [126]#011train-rmse:8.11292
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [127]#011train-rmse:8.11145
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [128]#011train-rmse:8.1098
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [129]#011train-rmse:8.10703
# [22:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [130]#011train-rmse:8.10504
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [131]#011train-rmse:8.1033
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [132]#011train-rmse:8.10049
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [133]#011train-rmse:8.09738
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [134]#011train-rmse:8.09506
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [135]#011train-rmse:8.09378
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [136]#011train-rmse:8.0914
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [137]#011train-rmse:8.08814
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [138]#011train-rmse:8.08514
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [139]#011train-rmse:8.08003
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [140]#011train-rmse:8.07764
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [141]#011train-rmse:8.07665
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [142]#011train-rmse:8.07428
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [143]#011train-rmse:8.07318
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [144]#011train-rmse:8.07176
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [145]#011train-rmse:8.0678
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [146]#011train-rmse:8.06598
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [147]#011train-rmse:8.06469
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [148]#011train-rmse:8.06421
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [149]#011train-rmse:8.06227
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=5
# [150]#011train-rmse:8.06109
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [151]#011train-rmse:8.05927
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [152]#011train-rmse:8.05782
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [153]#011train-rmse:8.05651
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [154]#011train-rmse:8.05506
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [155]#011train-rmse:8.05321
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [156]#011train-rmse:8.05216
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [157]#011train-rmse:8.05154
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [158]#011train-rmse:8.04871
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [159]#011train-rmse:8.04735
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [160]#011train-rmse:8.04604
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [161]#011train-rmse:8.04489
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [162]#011train-rmse:8.04312
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [163]#011train-rmse:8.04142
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [164]#011train-rmse:8.03871
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [165]#011train-rmse:8.03681
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [166]#011train-rmse:8.03571
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [167]#011train-rmse:8.03333
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [168]#011train-rmse:8.03162
# [22:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [169]#011train-rmse:8.02992
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [170]#011train-rmse:8.02779
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [171]#011train-rmse:8.02655
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [172]#011train-rmse:8.02287
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [173]#011train-rmse:8.02119
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [174]#011train-rmse:8.01918
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [175]#011train-rmse:8.01642
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [176]#011train-rmse:8.01499
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [177]#011train-rmse:8.01259
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=5
# [178]#011train-rmse:8.01227
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [179]#011train-rmse:8.01052
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=5
# [180]#011train-rmse:8.00623
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [181]#011train-rmse:8.00371
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [182]#011train-rmse:8.00291
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [183]#011train-rmse:8.0021
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [184]#011train-rmse:8.00127
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [185]#011train-rmse:7.99883
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [186]#011train-rmse:7.99575
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [187]#011train-rmse:7.99366
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [188]#011train-rmse:7.99255
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [189]#011train-rmse:7.99149
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [190]#011train-rmse:7.9884
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [191]#011train-rmse:7.98731
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [192]#011train-rmse:7.98637
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [193]#011train-rmse:7.98525
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [194]#011train-rmse:7.98336
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [195]#011train-rmse:7.98244
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [196]#011train-rmse:7.97943
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [197]#011train-rmse:7.97859
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [198]#011train-rmse:7.97802
# [22:56:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [199]#011train-rmse:7.97578
#
# 2023-12-23 22:56:56 Completed - Training job completed
# Training seconds: 117
# Billable seconds: 117

# %%
deployment = xgb_reg.deploy(
    #deployment options
    initial_instance_count=1, 
    instance_type='ml.m4.xlarge',
    #data_capture_config=data_capture_config
    )
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2023-12-23-23-07-39-803
# INFO:sagemaker:Creating endpoint-config with name xgboost-2023-12-23-23-07-39-803
# INFO:sagemaker:Creating endpoint with name xgboost-2023-12-23-23-07-39-803
# -----!

# %%
print(deployment.endpoint_name)
# Out:
# xgboost-2023-12-23-23-07-39-803
